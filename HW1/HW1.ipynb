# %%
from scipy.io import arff
import pandas as pd

# %%
data=arff.loadarff(r'C:\Users\10295\Desktop\data\4year.arff')
df=pd.DataFrame(data[0])

# %%
df['bankruptcy']=(df['class']==b'1')

# %%
df.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5     Attr6     Attr7    Attr8  \
# 0  0.159290  0.46240  0.07773  1.1683  -44.853  0.467020  0.189480  0.82895
# 1 -0.127430  0.46243  0.26917  1.7517    7.597  0.000925 -0.127430  1.16250
# 2  0.070488  0.23570  0.52781  3.2393  125.680  0.163670  0.086895  2.87180
# 3  0.136760  0.40538  0.31543  1.8705   19.115  0.504970  0.136760  1.45390
# 4 -0.110080  0.69793  0.18878  1.2713  -15.344  0.000000 -0.110080  0.43282
#
#     Attr9   Attr10     ...       Attr57   Attr58    Attr59   Attr60  Attr61  \
# 0  1.1223  0.38330     ...      0.41557  0.89101  0.001422   7.7928  4.9914
# 1  1.2944  0.53757     ...     -0.23704  1.06250  0.150410   5.4327  3.4629
# 2  1.0574  0.67689     ...      0.10413  0.94571  0.000000   7.1070  3.3808
# 3  1.1144  0.58938     ...      0.23203  0.89737  0.073024   6.1384  4.2241
# 4  1.7350  0.30207     ...     -0.36440  0.57153  0.000000  18.8010  2.7925
#
#     Attr62  Attr63   Attr64  class  bankruptcy
# ...

# %%
df.describe()
# Out:
#              Attr1        Attr2        Attr3         Attr4         Attr5  \
# count  9792.000000  9792.000000  9792.000000   9792.000000  9.792000e+03
# mean      0.043019     0.596404     0.130959      8.136600  6.465164e+01
# std       0.359303     4.586887     4.558841    290.008348  1.474355e+04
# min     -12.458000     0.000000  -445.910000     -0.045319 -3.794600e+05
# 25%       0.001322     0.263163     0.020384      1.048500 -5.100925e+01
# 50%       0.041374     0.467770     0.199290      1.598750  0.000000e+00
# 75%       0.111125     0.689183     0.410635      2.917825  5.626250e+01
# max      20.482000   446.910000    22.769000  27146.000000  1.034100e+06
#
#              Attr6        Attr7         Attr8        Attr9       Attr10  \
# count  9792.000000  9792.000000   9792.000000  9792.000000  9792.000000
# mean     -0.059273     0.059446     19.884016     1.882296     0.389040
# std       6.812406     0.533317    698.018755    17.674650     4.590064
# ...

# %%
sum(df.bankruptcy==True)
# Out:
# 515

# %%
df1=df[['Attr1','Attr2','Attr7','Attr10','class']]#Create a new dataframe with only 4 feataures

# %%
df1.columns=['x1','x2','x7','x10','class','bankruptcy']

# %%
df1.describe()
# Out:
#                 x1           x2           x7          x10
# count  9792.000000  9792.000000  9792.000000  9792.000000
# mean      0.043019     0.596404     0.059446     0.389040
# std       0.359303     4.586887     0.533317     4.590064
# min     -12.458000     0.000000   -12.458000  -445.910000
# 25%       0.001322     0.263163     0.003005     0.294510
# 50%       0.041374     0.467770     0.048840     0.510435
# 75%       0.111125     0.689183     0.126930     0.714285
# max      20.482000   446.910000    38.618000    12.602000

# %%
df1.head()
# Out:
#          x1       x2        x7      x10 class  bankruptcy
# 0  0.159290  0.46240  0.189480  0.38330  b'0'       False
# 1 -0.127430  0.46243 -0.127430  0.53757  b'0'       False
# 2  0.070488  0.23570  0.086895  0.67689  b'0'       False
# 3  0.136760  0.40538  0.136760  0.58938  b'0'       False
# 4 -0.110080  0.69793 -0.110080  0.30207  b'0'       False

# %%
for column in list(df.columns[df.isnull().sum() > 0]):
    mean_val = df[column].mean()
    df[column].fillna(mean_val, inplace=True)#Fill-in the missing values na with the mean

# %%
df.describe()#Fill-in the missing values na with the mean   all the count=9792
# Out:
#              Attr1        Attr2        Attr3         Attr4         Attr5  \
# count  9792.000000  9792.000000  9792.000000   9792.000000  9.792000e+03
# mean      0.043019     0.596404     0.130959      8.136600  6.465164e+01
# std       0.359303     4.586887     4.558841    290.008348  1.474355e+04
# min     -12.458000     0.000000  -445.910000     -0.045319 -3.794600e+05
# 25%       0.001322     0.263163     0.020384      1.048500 -5.100925e+01
# 50%       0.041374     0.467770     0.199290      1.598750  0.000000e+00
# 75%       0.111125     0.689183     0.410635      2.917825  5.626250e+01
# max      20.482000   446.910000    22.769000  27146.000000  1.034100e+06
#
#              Attr6        Attr7         Attr8        Attr9       Attr10  \
# count  9792.000000  9792.000000   9792.000000  9792.000000  9792.000000
# mean     -0.059273     0.059446     19.884016     1.882296     0.389040
# std       6.812406     0.533317    698.018755    17.674650     4.590064
# ...

# %%
df2=df1.loc[df1['bankruptcy']==True] # bankrupt companies 
df3=df1.loc[df1['bankruptcy']==False] # still-operating companies

# %%
df1.describe().iloc[1:3]#the mean and std of the 4 features among all
# Out:
#             x1        x2        x7       x10
# mean  0.043019  0.596404  0.059446  0.389040
# std   0.359303  4.586887  0.533317  4.590064

# %%
df2.describe().iloc[1:3]#the mean and std of the 4 features among  bankrupt  companies
# Out:
#             x1        x2        x7       x10
# mean -0.068873  0.878355 -0.061538  0.103367
# std   0.568076  1.945596  0.568432  1.946747

# %%
df3.describe().iloc[1:3]#the mean and std of the 4 features among  still-operating companies
# Out:
#             x1        x2        x7       x10
# mean  0.049231  0.580752  0.066162  0.404899
# std   0.343002  4.689694  0.530524  4.692934

# %%
sum((df1.x1<(0.043019-0.359303))&(df1.x10<(0.389040-4.590064)))#How many companies have X1 values 1 std below the mean
# Out:
# 15

# %%
df0=df1.loc[(df1.x1<(0.043019-0.359303))&(df1.x10<(0.389040-4.590064))]
df0
# Out:
#            x1       x2       x7      x10 class  bankruptcy
# 2312 -1.09270   5.6368 -1.09270  -4.6368  b'0'       False
# 2608 -3.72310  11.5300 -3.64240 -10.5300  b'0'       False
# 3017 -1.94800  25.0050 -1.94800 -24.0050  b'0'       False
# 3739 -0.72685   6.9334 -0.72685  -5.9334  b'0'       False
# 4767 -5.96550   6.6818 -5.96550  -5.6818  b'0'       False
# 5001 -3.28450  20.4030 -3.28450 -19.4030  b'0'       False
# 5259 -0.44000  16.4870 -0.44000 -15.4870  b'0'       False
# 5859 -0.32841   6.1187 -0.32841  -5.1187  b'0'       False
# 6264 -0.72755   5.2632 -0.72755  -4.2632  b'0'       False
# 7846 -1.98410  13.0630 -1.98410 -12.4730  b'0'       False
# 8405 -9.29810   9.6992 -9.29810  -8.6992  b'0'       False
# 8535 -1.37430   5.7326 -1.37430  -4.7326  b'0'       False
# 9584 -4.05060   6.5306 -4.05060  -5.5306  b'1'        True
# 9587 -0.65997  40.1570 -0.65997 -39.1560  b'1'        True
# 9662 -1.32900  15.0190 -1.32900 -14.0190  b'1'        True

# %%
sum(df0['bankruptcy']==True)/15
# Out:
# 0.2
